# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('sample_data.csv')

# %%
df.head()
# Out:
#     EID        Date             Time
# 0  2014  2022-01-01  01:35:47.744679
# 1  2005  2022-01-01  01:35:47.750678
# 2  2009  2022-01-01  01:35:47.757712
# 3  2023  2022-01-01  01:35:47.762680
# 4  2018  2022-01-01  01:35:47.767753

# %%
import plotly.express as px

fig = px.line(df, x='Time', y="Date")
fig.show()

# %%
plt.hist(df['EID'], bins=15)
# Out:
# (array([256., 252., 260., 260., 124., 246., 256., 255., 258., 124., 265.,
#         241., 246., 250., 248.]),
#  array([2004. , 2005.8, 2007.6, 2009.4, 2011.2, 2013. , 2014.8, 2016.6,
#         2018.4, 2020.2, 2022. , 2023.8, 2025.6, 2027.4, 2029.2, 2031. ]),
#  <BarContainer object of 15 artists>)
